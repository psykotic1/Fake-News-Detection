# %% [markdown]
# <a href="https://colab.research.google.com/github/psykotic1/Fake-News-Detection/blob/main/Fake_News_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fake News Detection using Machine Learning

# %%
#importing all the dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import re
import string
import os

from bs4 import BeautifulSoup
from textblob import TextBlob

# %%
#Importing the dataset with real news

# %%
true = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/True.csv")

# %%
#Showing the info of the dataset with real news articles with head() method

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
#Importing the dataset with fake news

# %%
fake = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Fake.csv")

# %%
#Showing the info of the dataset with fake news articles with head() method

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  object
#  1   text     21417 non-null  object
#  2   subject  21417 non-null  object
#  3   date     21417 non-null  object
# dtypes: object(4)
# memory usage: 669.4+ KB

# %%
fake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB

# %%
#Marking the real news with 0 and fake news with 1 to know what news is legit

# %%
true['target'] = 0

# %%
fake['target'] = 1

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  target
# 0  December 31, 2017        0
# 1  December 29, 2017        0
# 2  December 31, 2017        0
# 3  December 30, 2017        0
# 4  December 29, 2017        0

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  target
# 0  December 31, 2017       1
# 1  December 31, 2017       1
# 2  December 30, 2017       1
# 3  December 29, 2017       1
# 4  December 25, 2017       1

# %%
#Concatenating both the datasets to make it one combined dataset

# %%
df = [true, fake]
data = pd.concat(df, ignore_index=True)

# %%
# Adding some extra info into the dataset like words count, digits, characters etc
# to find some kind of pattern between fake and real news

# %%
#words count

def words_count(df):
    length = len(str(df).split())
    return length

# characters count

def char_count(df):
    string = df.split()
    x = ''.join(string)
    return len(x)

# hashtags count

def hashtag_count(df):
    hashtag = len([t for t in df.split() if t.startswith('#')])
    return hashtag

# digits count

def digits_count(df):
    digits = re.findall(r'[0-9]+', df)
    return digits

def get_features(df):
    df['words_count'] = df['text'].apply(lambda x: words_count(x))
    df['char_count'] = df['text'].apply(lambda x: char_count(x))
    df['hashtags_count'] = df['text'].apply(lambda x: hashtag_count(x))
    df['digits_count'] = df['text'].apply(lambda x: digits_count(x))

    return df

# %%
data = get_features(data)

# %%
data.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  target  words_count  char_count  hashtags_count  \
# 0  December 31, 2017        0          749        3907               0
# 1  December 29, 2017        0          624        3453               0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           44898 non-null  object
#  1   text            44898 non-null  object
#  2   subject         44898 non-null  object
#  3   date            44898 non-null  object
#  4   target          44898 non-null  int64
#  5   words_count     44898 non-null  int64
#  6   char_count      44898 non-null  int64
#  7   hashtags_count  44898 non-null  int64
#  8   digits_count    44898 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 3.1+ MB

# %%
#Configuring the style and size settings for matplotlib plots using the 'ggplot' style

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = [4,4]
plt.rcParams['figure.dpi'] = 120

# %%
#Creates a count plot based on the 'target' column from the 'data' DataFrame based on no of characters

# %%
sns.countplot(x='target', data=data)
plt.title('Counts')
# Out:
# Text(0.5, 1.0, 'Counts')

# %%
#Correlation between the 'words count' and 'target' columns in the 'data' DataFrame

# %%
sns.catplot(x='target', y='words_count', kind='bar', data=data)
plt.rcParams['figure.figsize'] = [4,4]
plt.xlabel('0 - True news  ||  Fake news - 1')
plt.title('Correlation between number of words and target')
# Out:
# Text(0.5, 1.0, 'Correlation between number of words and target')

# %%
#Correlation between the 'hashtags' and 'target' columns in the 'data' DataFrame

# %%
sns.catplot(x='target', y='hashtags_count', kind='bar', data=data)
plt.rcParams['figure.figsize'] = [4,4]
plt.xlabel('0 - True news  ||  Fake news - 1')
plt.title('Correlation between hashtags and target')
# Out:
# Text(0.5, 1.0, 'Correlation between hashtags and target')

# %%
plt.rcParams['figure.figsize'] = [10,8]

sns.catplot(x='target', y='words_count', kind='bar', data=data, hue='subject')
plt.xlabel('0 - True news  ||  Fake news - 1')
# Out:
# Text(0.5, 37.000000000000014, '0 - True news  ||  Fake news - 1')

# %%
# Now we have to clean the data

# %%
data['text'][1]
# Out:
# 'WASHINGTON (Reuters) - Transgender people will be allowed for the first time to enlist in the U.S. military starting on Monday as ordered by federal courts, the Pentagon said on Friday, after President Donald Trump’s administration decided not to appeal rulings that blocked his transgender ban. Two federal appeals courts, one in Washington and one in Virginia, last week rejected the administration’s request to put on hold orders by lower court judges requiring the military to begin accepting transgender recruits on Jan. 1. A Justice Department official said the administration will not challenge those rulings. “The Department of Defense has announced that it will be releasing an independent study of these issues in the coming weeks. So rather than litigate this interim appeal before that occurs, the administration has decided to wait for DOD’s study and will continue to defend the president’s lawful authority in District Court in the meantime,” the official said, speaking on conditio
# ...

# %%
# For data cleaning we perform tasks like Tokenization, Stemming, removing punctuation

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.porter import *

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

p_stemming = PorterStemmer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def nltk_process(data):
    # Tokenization
    tokenList = word_tokenize(data)

    # Stemming
    stemedList = []
    for word in tokenList:
        stemedList.append(p_stemming.stem(word))

    # Lemmatization
    wordnet_lemmatizer = WordNetLemmatizer()
    lemmaList = []
    for word in stemedList:
        lemmaList.append(wordnet_lemmatizer.lemmatize(word))

    # Stopwords
    filtered_words = []
    nltk_stop_words = set(stopwords.words("english"))
    for word in lemmaList:
        if word not in nltk_stop_words:
            filtered_words.append(word)

    # Remove punct.

    for word in filtered_words:
        if word in string.punctuation:
            filtered_words.remove(word)

    return filtered_words

# %%
# data['text'][1]

# %%
# To calculate the time taken to execute

# %%
# %%time
data['text'] = data['text'].apply(lambda x: nltk_process(x))
# Out:
# CPU times: user 10min 33s, sys: 3.94 s, total: 10min 37s
# Wall time: 11min 2s

# %%
data['text'][1]
# Out:
# ['washington',
#  'reuter',
#  'transgend',
#  'peopl',
#  'allow',
#  'first',
#  'time',
#  'enlist',
#  'u.s.',
#  'militari',
#  'start',
#  'monday',
#  'order',
#  'feder',
#  'court',
#  'pentagon',
#  'said',
#  'friday',
#  'presid',
#  'donald',
#  'trump',
#  '’',
#  'administr',
#  'decid',
#  'appeal',
#  'rule',
#  'block',
#  'hi',
#  'transgend',
#  'ban',
#  'two',
#  'feder',
#  'appeal',
#  'court',
#  'one',
#  'washington',
#  'one',
#  'virginia',
#  'last',
#  'week',
#  'reject',
#  'administr',
#  '’',
#  'request',
#  'put',
#  'hold',
#  'order',
#  'lower',
#  'court',
#  'judg',
#  'requir',
#  'militari',
#  'begin',
#  'accept',
#  'transgend',
#  'recruit',
#  'jan.',
#  '1',
#  'justic',
#  'depart',
#  'offici',
#  'said',
#  'administr',
#  'challeng',
#  'rule',
#  '“',
#  'depart',
#  'defens',
#  'ha',
#  'announc',
#  'releas',
#  'independ',
#  'studi',
#  'issu',
#  'come',
#  'week',
#  'rather',
#  'litig',
#  'thi',
#  'interim',
# ...

# %%
data['text'] = [" ".join(text) for text in data['text'].values]

# %%
data['text'][1]
# Out:
# 'washington reuter transgend peopl allow first time enlist u.s. militari start monday order feder court pentagon said friday presid donald trump ’ administr decid appeal rule block hi transgend ban two feder appeal court one washington one virginia last week reject administr ’ request put hold order lower court judg requir militari begin accept transgend recruit jan. 1 justic depart offici said administr challeng rule “ depart defens ha announc releas independ studi issu come week rather litig thi interim appeal befor occur administr ha decid wait dod ’ studi continu defend presid ’ law author district court meantim ” offici said speak condit anonym septemb pentagon said creat panel senior offici studi implement direct trump prohibit transgend individu serv defens depart ha feb. 21 submit plan trump lawyer repres currently-serv transgend servic member aspir recruit said expect administr appeal rule conservative-major suprem court hope would happen pentagon spokeswoman heather babb sa
# ...

# %%
# Creates TF-IDF (Term Frequency-Inverse Document Frequency) finds how releventa word is to the given document

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
tfidf = TfidfVectorizer(lowercase=False, stop_words='english')

# %%
# Separates the transformed text data into the input feature matrix (X) and the target vector (y).

# %%
text = data['text']
X = tfidf.fit_transform(text)
y = data['target']

# %%
data.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  washington reuter - head conserv republican fa...  politicsNews
# 1  washington reuter transgend peopl allow first ...  politicsNews
# 2  washington reuter - special counsel investig l...  politicsNews
# 3  washington reuter - trump campaign advis georg...  politicsNews
# 4  seattle/washington reuter - presid donald trum...  politicsNews
#
#                  date  target  words_count  char_count  hashtags_count  \
# 0  December 31, 2017        0          749        3907               0
# 1  December 29, 2017        0          624        3453               0
# ...

# %%
# Performs a train-test split on the TF-IDF matrix 'X' and the target labels 'y'

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 777)

# %%
#X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
# Now preparing the model to use SVM Algorithm to test its accuracy

# %%
from sklearn.svm import LinearSVC

# %%
# Makes predictions on the test set, and prints the classification report to evaluate the model's performance

# %%
clf_svc = LinearSVC()
clf_svc.fit(X_train, y_train)
y_pred = clf_svc.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      4246
#            1       1.00      1.00      1.00      4734
#
#     accuracy                           1.00      8980
#    macro avg       1.00      1.00      1.00      8980
# weighted avg       1.00      1.00      1.00      8980

# %%
#print(confusion_matrix(y_test, y_pred))

# %%
clf_svc.score(X_test, y_test)
# Out:
# 0.9955456570155902
